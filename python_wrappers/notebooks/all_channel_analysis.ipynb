# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import glob
import os

import configparser
import json
import scipy.stats
from scipy.optimize import curve_fit
from matplotlib.colors import LogNorm
import datetime
import pandas as pd
# %run ../WaveformProcessor.py
# %run ../FastProcessing.py
# %run ../FitSPE.py

sys.path.insert(0,"../src/")
import common.d2d as d2d
import common.utils as utils
import common.config_reader as common_config_reader
import data_processing.waveform_processor as waveform_processor
import data_processing.fast_processor as fast_processor
import common.metadata_handler as metadata_handler

# %%
import sys
sys.path.insert(0,"../src/")
import common.config_reader as common_config_reader
common_cfg_reader = common_config_reader.ConfigurationReader()
path_config = common_cfg_reader.get_absolute_path_config()

sandpro_path = path_config.get("PROCESSING_TOOL", "sandpro_dir")

sys.path.insert(0,sandpro_path)
import sandpro

# %%
spe_dict = {-46.0:[0.375,
                   0.375, 
                   0.375,
                    0.3910751695618168,
                    0.4261823299244276,
                    0.4184525855516032,
                    0.3734331004141874,
                    0.35296444982085795,
                    0.3827113197936082,
                    0.3653657388092717,
                    0.375,
                    0.3567998500554362,
                    0.38616036904292744,
                    0.367455862694989,
                    0.3868351542419548,
                    0.33741408343639806,
                    0.32861877382475013,
                    0.3789985771594436,
                    0.38827769181400945,
                    0.3542945895460527,
                    0.40725790000923273,
                    0.3277967822639769,
                    0.3145687034227316,
                    0.375],
            -47.0:[0.375,
                   0.375, 
                   0.375,
                    0.3910751695618168,
                    0.4261823299244276,
                    0.4184525855516032,
                    0.3734331004141874,
                    0.35296444982085795,
                    0.3827113197936082,
                    0.3653657388092717,
                    0.375,
                    0.3567998500554362,
                    0.38616036904292744,
                    0.367455862694989,
                    0.3868351542419548,
                    0.33741408343639806,
                    0.32861877382475013,
                    0.3789985771594436,
                    0.38827769181400945,
                    0.3542945895460527,
                    0.40725790000923273,
                    0.3277967822639769,
                    0.3145687034227316,
                    0.375]
            }

# %%
def get_n_channel_for_board(processing_mode, board_number):
    # get number of channels per events
    if processing_mode == "single_channel":
        n_channels = 1
    elif processing_mode == "all_channel_12":
        # NEW
        if board_number == 0: # NEW
            n_channels = 12 # NEW
        else:  # NEW
            n_channels = 12 # NEW
            # NEW: removed processing mode as integer (between 0 and 24)
        # n_channels = 1
    elif processing_mode == "all_channel_16":
        # NEW
        if board_number == 0: # NEW
            n_channels = 16 # NEW
        else:  # NEW
            n_channels = 8 # NEW
            # NEW: removed processing mode as integer (between 0 and 24)
    else:
        raise ValueError(f"Processing mode {processing_mode} not recognized")
    
    return n_channels

# %% [markdown]
# ### Settings

# %%
class Analysis:
    def __init__(self, data_folder: list,
                 set_name: str,
                 processing_mode: str):
        
        self.processing_mode = processing_mode
        self.data_folder = data_folder
        self.set_name = set_name
        
        self.meta_data_file = glob.glob(f"{data_folder}/meta_{set_name}.json")
        self.bin_data_files = glob.glob(f"{data_folder}/{set_name}*.bin")

        print(f"Found {len(self.bin_data_files)} binary data file: \n{self.bin_data_files}")
        print(f"Found {len(self.meta_data_file)} meta data file: \n{self.meta_data_file}")

        with open(self.meta_data_file[0], "r") as file:
            meta_data = json.load(file)
        
        self.common_cfg_reader = common_config_reader.ConfigurationReader()
        config = self.common_cfg_reader.get_data_processing_config()


        # self.number_of_events = meta_data["number_of_events"] # from argument or metadata # NEW
        self.number_of_events = int(meta_data["number_of_events"])
        self.record_length_sample = int(meta_data["record_length"]) # from argument or metadata # NEW
        truncate_event_front = int(config.get("EVENT_PROCESSOR_SETTINGS", "truncate_event_front")) #index to truncate the events before
        truncate_event_back = int(config.get("EVENT_PROCESSOR_SETTINGS", "truncate_event_back")) #index to truncate the events before
        self.start_index, self.end_index = truncate_event_front, self.number_of_events - truncate_event_back -1 #first 1000 events are noisy # the last 500 events might be empty

        self.baseline_n_samples = int(config.get("EVENT_PROCESSOR_SETTINGS", "n_baseline_samples")) #index to truncate the events before
        self.baseline_n_samples_avg = int(config.get("EVENT_PROCESSOR_SETTINGS", "n_baseline_samples_avg")) #index to truncate the events before

        # get integral window to compute area
        tmp = config.get("EVENT_PROCESSOR_SETTINGS", "integral_window_for_area")
        tmp = tmp.split(' ')
        # integral_window = (float(tmp[0]), float(tmp[1]))
        # self.integral_window = (0.2, 0.55)
        self.integral_window = (0.25, 0.4)
        # self.integral_window = (0.3, 0.55)
        # self.integral_window = (0.2, 0.8)

        data_taking_config = self.common_cfg_reader.get_data_taking_config()
        DAQ = data_taking_config.get("DAQ_MODULE", "DAQ") # which DAQ board

        self.n_bits = int(data_taking_config.get(DAQ, "n_bits"))
        self.vpp_range = float(data_taking_config.get(DAQ, "range"))

        self.volt_per_adc = self.vpp_range/float(2**self.n_bits)
                    
        self.waveform = None
        
        self.comment = meta_data["comment"] # from argument or metadata # NEW
        self.run_tag = meta_data["run_tag"] # from argument or metadata # NEW
        self.voltage = meta_data["voltage_config"]["preamp_1"] # from argument or metadata # NEW
        
        
    def get_results(self):

        baseline_std_V_list = []
        baseline_mean_V_list = []
        
        event_time_s_list = []
        
        areas_Vns_list = []
        heights_V_list = []
        rise_time_ns_list = []
        areas_PE_list = []
        
        randomly_selected_raw_WF_V_list = []
        randomly_selected_filtered_WF_list = []

        sum_start_list = []
        sum_end_list = []
        

        n_selection = 100

        for board_num, bin_full_path in enumerate(self.bin_data_files): # FIXME: board_num might be wrong

            n_channels = get_n_channel_for_board(self.processing_mode, board_num)

            process_config = {"nchs": int(n_channels),
                        "nsamps": int(self.record_length_sample),
                        "sample_selection": int(self.baseline_n_samples), 
                        "samples_to_average": int(self.baseline_n_samples_avg)}

            # dump the config to a json file
            sandpro_process_config_fname = self.common_cfg_reader.get_sandpro_process_config_path()
            with open(sandpro_process_config_fname, "w") as f:
                json.dump(process_config, f, indent=4)
                

            processor= sandpro.processing.rawdata.RawData(config_file = sandpro_process_config_fname,
                                                        perchannel=False) # what does this perchannel mean?
            
            self.waveform = processor.get_rawdata_numpy(n_evts=self.number_of_events-1,
            file=bin_full_path, # specific .bin file
            bit_of_daq=self.n_bits,
            headersize=4,inversion=False)
            
            for channel in np.arange(n_channels,dtype=int):
                # print(waveform["data_per_channel"][start_index:end_index,i,:].shape)
                wfp = waveform_processor.WFProcessor(self.data_folder, 
                            length_per_event = self.record_length_sample,
                            volt_per_adc=self.volt_per_adc)

                data_processed = self.waveform["data_per_channel"][self.start_index:self.end_index,channel,:]# in mV
                event_time_s = self.waveform['microseconds'][self.start_index:self.end_index]/1e6
                
                wfp.set_data(data_processed, unit="mV")
                wfp.process_wfs()
                
                baseline_std_V = np.mean(wfp.baseline_std_V)
                baseline_mean_V = np.mean(wfp.baseline_mean_V)
                
                n_processed_events = int(len(wfp.baseline_std_V))
                
                areas_Vns = wfp.get_area(sum_window=self.integral_window)

                # areas_Vns = wfp.get_area(sum_window=self.integral_window, 
                #                         consecutive_samples=2, 
                #                         threshold_sig=3.0)
                # sum_start = wfp.sum_start_list
                # sum_end = wfp.sum_end_list
                heights_V = wfp.get_height(search_window=self.integral_window)
                rise_time_ns = wfp.get_rise_time_ns(search_window=self.integral_window)
                
                baseline_std_V_list.append(baseline_std_V)
                baseline_mean_V_list.append(baseline_mean_V)
                
                areas_Vns_list.append(areas_Vns)
                heights_V_list.append(heights_V)
                rise_time_ns_list.append(rise_time_ns)
                event_time_s_list.append(event_time_s)
                areas_PE_list.append(areas_Vns/spe_dict[self.voltage][channel])

                all_rows_id = np.arange(n_processed_events)
                selected_rows_id = np.random.choice(all_rows_id, size=n_selection, replace=False)
                # is because np.random.randint do not have replace option

                randomly_selected_raw_WF_V_list.append(data_processed[selected_rows_id,:])
                randomly_selected_filtered_WF_list.append(wfp.filtered_wfs[selected_rows_id,:])

                # sum_start_list.append(sum_start[selected_rows_id])
                # sum_end_list.append(sum_end[selected_rows_id])
            

            self.baseline_std_V_list = baseline_std_V_list
            self.baseline_mean_V_list = baseline_mean_V_list
            self.areas_Vns_list = areas_Vns_list
            self.heights_V_list = heights_V_list
            self.rise_time_ns_list = rise_time_ns_list
            self.event_time_s_list = event_time_s_list
            self.areas_PE_list = areas_PE_list
            self.randomly_selected_raw_WF_V_list = randomly_selected_raw_WF_V_list
            self.randomly_selected_filtered_WF_list = randomly_selected_filtered_WF_list
            # self.sum_start_list = sum_start_list
            # self.sum_end_list = sum_end_list

        return

# %% [markdown]
# ### Load data

# %%
# Cs137
data_folder = "/kalinka/storage/darkmatter/XENONnT/sk6801/UCSD_data/raw_data/202410_LXe_new/20241022_all_3_T98_all_voltages_3.0sig/"
set_name = "config_all_20241022_171411"
processing_mode = "all_channel_12" # from argument


# data_folder = "/kalinka/storage/darkmatter/XENONnT
# /sk6801/UCSD_data/raw_data/202410_LXe/20241018_all_T98_all_voltages_3.0sig/"
# set_name = "config_all_20241018_125926"
# processing_mode = "all_channel_16" # from argument

analysis_primary_info = Analysis(data_folder, set_name, processing_mode)
analysis_primary_info.get_results()



# data_folder = "/home/daqtest/DAQ/SandyAQ_vera/SandyAQ/softlink_to_data/all_data/202410_LXe_new/20241028_all_4_T98_all_voltages_4.0sig"
# set_name = "config_all_20241022_172116"
# processing_mode = "all_channel_12" # from argument or metadata # NEW


# for comparison between two runs
# analysis_secondary_info = Analysis(data_folder, set_name, processing_mode)
# analysis_secondary_info.get_results()

# analysis_info_list = [analysis_primary_info, analysis_secondary_info]
analysis_info_list = [analysis_primary_info]

# %%
plt.close("all")

# %%
event_time = analysis_primary_info.event_time_s_list
# (np.array(event_time[0::10])-np.array(event_time[9::10]))

# %%
event_time

# %%
plt.plot(event_time[16])
plt.title("Event time")

# %%
plt.plot(event_time[12]-event_time[11])
plt.title("trigger time difference")
plt.xlabel("Event number")
plt.ylabel("board 1 - board 0 [s]")

# %% [markdown]
# ### Plots

# %% [markdown]
# #### waveform

# %%
analysis_info = analysis_primary_info

# %%
# plot waveforms

analysis_info = analysis_primary_info

plt.close("all")
plt.rcParams.update({'font.size': 15})

for channel in np.arange(1,dtype=int):

    figure, axes = plt.subplots(3,2,figsize=(10,10))
    # figure.subplots_adjust(wspace=0.5)
    figure.subplots_adjust(hspace=0.3)
    time = np.arange(0, analysis_info.record_length_sample, 1) * 4

    randomly_selected_raw_WF_V = np.transpose(analysis_info.randomly_selected_raw_WF_V_list[channel])
    randomly_selected_filtered_WF_V = np.transpose(analysis_info.randomly_selected_filtered_WF_list[channel])

    axes[0,0].set_title(f"Raw WFs channel {channel}")
    axes[0,0].plot(time, 1000 * randomly_selected_raw_WF_V,color="red",alpha=0.2)

    _ymax = 1800
    axes[0,0].set_xlim(0,time[-1]-100)
    axes[0,0].set_ylim(200,_ymax)
    axes[0,0].set_ylabel("Voltage [mV]")
    axes[0,0].set_xlabel("Time [ns]")

    # plot intergral window
    axes[0,0].fill_betweenx([200,_ymax], 
                            analysis_info.integral_window[0]*np.max(time), 
                            analysis_info.integral_window[1]*np.max(time), 
                            color='gray', alpha=0.5)
    
    # plot intergral window
    # axes[0,0].axvline(analysis_info.sum_start_list*4, color='blue', linestyle='--', alpha=0.2)
    # axes[0,0].axvline(analysis_info.sum_start_list*4, color='blue', linestyle='--', alpha=0.2)

    axes[0,1].set_title(f"Filtered WFs channel {channel}")
    axes[0,1].plot(time, 1000 * randomly_selected_filtered_WF_V,color="red",alpha=0.2)

    axes[0,1].set_xlim(0,time[-1]-100)
    axes[0,1].set_ylim(-5,1600)
    axes[0,1].set_ylabel("Voltage [mV]")
    axes[0,1].set_xlabel("Time [ns]")



    axes[1,0].set_title(f"Zoomed raw WFs channel {channel}")
    axes[1,0].plot(time, 1000 * randomly_selected_raw_WF_V,color="red",alpha=0.2)

    _ymax = 350
    axes[1,0].set_xlim(0,time[-1]-100)
    axes[1,0].set_ylim(200,_ymax)
    axes[1,0].set_ylabel("Voltage [mV]")
    axes[1,0].set_xlabel("Time [ns]")

    point_in_middle = time[int(len(time)/2)]

    # plot intergral window
    axes[1,0].fill_betweenx([200,_ymax], 
                            analysis_info.integral_window[0]*np.max(time), 
                            analysis_info.integral_window[1]*np.max(time), 
                            color='gray', alpha=0.5)
    
    # plot intergral window
    # axes[0,0].axvline(analysis_info.sum_start*4, color='blue', linestyle='--')
    # axes[0,0].axvline(analysis_info.sum_end*4, color='blue', linestyle='--')

    axes[1,0].axhline(1000 * analysis_info.baseline_mean_V_list[channel], color="gray",linestyle="dashed",label=f"Baseline mean", zorder=10)

    # labels
    _ypos = 280
    axes[1,0].text(100,_ypos,f"baseline mean: {1000 * analysis_info.baseline_mean_V_list[channel]:.1f} mV")
    _ypos = 260
    axes[1,0].text(100,_ypos,f"baseline std: {1000 * analysis_info.baseline_std_V_list[channel]:.2f} mV")



    axes[1,1].set_title(f"Zoomed filtered WFs channel {channel}")
    axes[1,1].plot(time, 1000 * randomly_selected_filtered_WF_V,color="red",alpha=0.2)

    _ymax = 40
    axes[1,1].set_xlim(0,time[-1]-100)
    axes[1,1].set_ylim(-5,_ymax)
    axes[1,1].set_ylabel("Voltage [mV]")
    axes[1,1].set_xlabel("Time [ns]")


    axes[2,0].set_title(f"Integrated area distribution channel {channel}")
    axes[2,0].hist(analysis_info.areas_Vns_list[channel],
                    bins=200,
                    range=(-0.1, 6),
                    histtype='step',
                    color='red', 
                    label="Integrated area")
    axes[2,0].set_yscale("log")
    axes[2,0].set_ylabel("Count")
    axes[2,0].set_xlabel("Integrated Area [$V\cdot ns$]")
    axes[2,0].set_ylim(1e-1,None)

plt.show()
plt.close()

# %%
plt.close("all")

# %%
plt.close()

fig, axes = plt.subplots(3,8,figsize=(35,15))
title_text = ""

for analysis_info in analysis_info_list:
    for channel in np.arange(24):
        height_V = analysis_info.heights_V_list[channel]
        area_Vns = analysis_info.areas_Vns_list[channel]

        plot_row = channel % 3
        plot_col = channel // 3

        # change the rows so that it match with the physical layout of the channels
        if plot_row == 0:
            plot_row = 1
        elif plot_row == 1:
            plot_row = 0

        axes[plot_row,plot_col].hist2d(area_Vns,height_V,
                                bins=[100,100],
                                range=[[-0.1,800],[0,2]],
                                cmap='viridis',
                                norm=LogNorm())
        
        axes[plot_row,plot_col].set_title(f"Channel {channel}")

    # set the labels
    for ax in axes.flat:
        ax.set(xlabel='Area [V*ns]', ylabel='Height [V]')

    # Set plot title
    if data_folder[-1] == "/":
        data_folder = data_folder[:-1]
    plt.suptitle(f"Dataset: {data_folder.split('/')[-1]}")

    # Move title upwards
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])

    plt.show()

# %% [markdown]
# #### Height vs area

# %%
# rise time
plt.close()
plt.rcParams.update({'font.size': 25})

fig, axes = plt.subplots(3,8,figsize=(35,15), sharex=True, sharey=True, gridspec_kw={'hspace': 0, 'wspace': 0})
# plt.subplots_adjust(wspace=0, hspace=0)

area_Vns_range = 700

analysis_info = analysis_primary_info
title_text = ""

if analysis_info.data_folder[-1] == "/":
    subdir = analysis_info.data_folder.split('/')[-2]
else:
    subdir = analysis_info.data_folder.split('/')[-1]
    
title_text += f"\n\nDataset: {subdir}/{analysis_info.set_name}\n   comment: {analysis_info.comment}\n   tag: {analysis_info.run_tag}\n   bias voltage: {analysis_info.voltage}"

for channel in np.arange(24):
    
    area_Vns = analysis_info.areas_Vns_list[channel]
    height_V = analysis_info.heights_V_list[channel]

    plot_row = channel % 3
    plot_col = channel // 3

    # change the rows so that it match with the physical layout of the channels
    if plot_row == 0:
        plot_row = 1
    elif plot_row == 1:
        plot_row = 0

    axes[plot_row,plot_col].hist2d(area_Vns,height_V,
                            bins=[100,100],
                            range=[[-0.1,800],[0,2]],
                            cmap='viridis',
                            norm=LogNorm())
    
    axes[plot_row,plot_col].set_title(f"Channel {channel}", y=0.9, va="top")
    
    if plot_row !=2: 
        axes[plot_row,plot_col].xaxis.set_visible(False)
    if plot_col != 0: 
        axes[plot_row,plot_col].yaxis.set_visible(False)
        

# set the labels
for ax in axes.flat:
    ax.set(xlabel='Area [V*ns]', ylabel='Height [V]')

# Set plot title
if data_folder[-1] == "/":
    data_folder = data_folder[:-1]
plt.suptitle(title_text, x=0.2, horizontalalignment='left', )

# Move title upwards
plt.tight_layout()

plt.show()

# %% [markdown]
# #### baseline

# %%
# baseline
plt.close()
plt.rcParams.update({'font.size': 25})

fig, ax = plt.subplots(figsize=(35,15))
# plt.subplots_adjust(wspace=0, hspace=0)

analysis_info = analysis_primary_info
title_text = ""

if analysis_info.data_folder[-1] == "/":
    subdir = analysis_info.data_folder.split('/')[-2]
else:
    subdir = analysis_info.data_folder.split('/')[-1]
    
title_text += f"\n\nDataset: {subdir}/{analysis_info.set_name}\n   comment: {analysis_info.comment}\n   tag: {analysis_info.run_tag}\n   bias voltage: {analysis_info.voltage}"

heatmap_array = np.zeros((3,8))

for channel in np.arange(24):
    
    baseline_std_mV = analysis_info.baseline_std_V_list[channel]*1000

    plot_row = channel % 3
    plot_col = channel // 3

    # change the rows so that it match with the physical layout of the channels
    if plot_row == 0:
        plot_row = 1
    elif plot_row == 1:
        plot_row = 0
        
    heatmap_array[plot_row, plot_col] = baseline_std_mV
        
    text = ax.text(plot_col, plot_row, f"Channel {channel}\n{baseline_std_mV:.2f}",
                    ha="center", va="center", color="orange")
    
ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
im = ax.imshow(heatmap_array, cmap='viridis',vmin=0)

# Set plot title
if data_folder[-1] == "/":
    data_folder = data_folder[:-1]
plt.title(title_text, x=0.2, horizontalalignment='left')

plt.colorbar(im, label="Frequency")
plt.tight_layout()

plt.show()

# %% [markdown]
# #### rise time

# %%
# rise time
plt.close()

fig, axes = plt.subplots(3,8,figsize=(35,15))
rise_time_range = 250
# area_Vns_range = np.max(areas_Vns_list)
area_Vns_range = 1400

analysis_info_list = [analysis_primary_info]
title_text = ""

for analysis_info in analysis_info_list:
    for channel in np.arange(24):
        area_Vns = analysis_info.areas_Vns_list[channel]
        rise_time_ns = analysis_info.rise_time_ns_list[channel]

        plot_row = channel % 3
        plot_col = channel // 3

        # change the rows so that it match with the physical layout of the channels
        if plot_row == 0:
            plot_row = 1
        elif plot_row == 1:
            plot_row = 0

        axes[plot_row,plot_col].hist2d(area_Vns,rise_time_ns,
                                bins=[100,int(rise_time_range/4)],
                                range=[[-0.1,area_Vns_range],[0,rise_time_range]],
                                cmap='viridis',
                                norm=LogNorm())
        
        axes[plot_row,plot_col].set_title(f"Channel {channel}")
        
        title_text += f"Dataset: {analysis_info.data_folder.split('/')[-1]}/{analysis_info.set_name}"
    
    

# set the labels
for ax in axes.flat:
    ax.set(xlabel='Area [V*ns]', ylabel='Rise Time [ns]')

# Set plot title
if data_folder[-1] == "/":
    data_folder = data_folder[:-1]
plt.suptitle(f"Dataset: {data_folder.split('/')[-1]}/{set_name}")

# Move title upwards
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

plt.show()

# %% [markdown]
# #### area 1D

# %%
# rise time
plt.close()
plt.rcParams.update({'font.size': 25})

fig, axes = plt.subplots(3,8,figsize=(35,15), sharex=True, sharey=True, gridspec_kw={'hspace': 0, 'wspace': 0})
# plt.subplots_adjust(wspace=0, hspace=0)

area_Vns_range = 700

# analysis_info_list = [analysis_primary_info, analysis_secondary_info]
# color_list = ["tab:blue", "tab:orange"]
analysis_info_list = [analysis_primary_info]
color_list = ["tab:blue"]
title_text = ""

for analysis_info, color in zip(analysis_info_list,color_list):
    if analysis_info.data_folder[-1] == "/":
        subdir = analysis_info.data_folder.split('/')[-2]
    else:
        subdir = analysis_info.data_folder.split('/')[-1]
        
    title_text += f"\n\nDataset: {subdir}/{analysis_info.set_name}\n   color: {color}\n   comment: {analysis_info.comment}\n   tag: {analysis_info.run_tag}\n   bias voltage: {analysis_info.voltage}"
    
    for channel in np.arange(24):
        
        area_Vns = analysis_info.areas_Vns_list[channel]

        plot_row = channel % 3
        plot_col = channel // 3

        # change the rows so that it match with the physical layout of the channels
        if plot_row == 0:
            plot_row = 1
        elif plot_row == 1:
            plot_row = 0

        axes[plot_row,plot_col].hist(area_Vns,
                                bins=100,
                                range=[-0.1,area_Vns_range],
                                color=color,
                                alpha = 0.5)
        
        axes[plot_row,plot_col].set_title(f"Channel {channel}", y=0.9, va="top")
        axes[plot_row,plot_col].set_yscale("log")
        
        if plot_row !=2: 
            axes[plot_row,plot_col].xaxis.set_visible(False)
        if plot_col != 0: 
            axes[plot_row,plot_col].yaxis.set_visible(False)
        

# set the labels
for ax in axes.flat:
    ax.set(xlabel='Area [V*ns]', ylabel='Count')

# Set plot title
if data_folder[-1] == "/":
    data_folder = data_folder[:-1]
plt.suptitle(title_text, x=0.2, horizontalalignment='left', )

# Move title upwards
plt.tight_layout()

plt.show()

# %%
# area
plt.close()
plt.rcParams.update({'font.size': 25})

fig, axes = plt.subplots(3,8,figsize=(35,15), sharex=True, sharey=True, gridspec_kw={'hspace': 0, 'wspace': 0})
# plt.subplots_adjust(wspace=0, hspace=0)

area_Vns_range = 700

# analysis_info_list = [analysis_primary_info, analysis_secondary_info]
# color_list = ["tab:blue", "tab:orange"]
analysis_info_list = [analysis_primary_info]
color_list = ["tab:blue"]
title_text = ""

for analysis_info, color in zip(analysis_info_list,color_list):
    if analysis_info.data_folder[-1] == "/":
        subdir = analysis_info.data_folder.split('/')[-2]
    else:
        subdir = analysis_info.data_folder.split('/')[-1]
        
    title_text += f"\n\nDataset: {subdir}/{analysis_info.set_name}\n   color: {color}\n   comment: {analysis_info.comment}\n   tag: {analysis_info.run_tag}\n   bias voltage: {analysis_info.voltage}"
    
    for channel in np.arange(24):
        
        area = analysis_info.areas_PE_list[channel]

        plot_row = channel % 3
        plot_col = channel // 3

        # change the rows so that it match with the physical layout of the channels
        if plot_row == 0:
            plot_row = 1
        elif plot_row == 1:
            plot_row = 0

        axes[plot_row,plot_col].hist(area,
                                bins=100,
                                range=[-0.1,area_Vns_range],
                                color=color,
                                alpha = 0.5)
        
        axes[plot_row,plot_col].set_title(f"Channel {channel}", y=0.9, va="top")
        axes[plot_row,plot_col].set_yscale("log")
        
        if plot_row !=2: 
            axes[plot_row,plot_col].xaxis.set_visible(False)
        if plot_col != 0: 
            axes[plot_row,plot_col].yaxis.set_visible(False)
        

# set the labels
for ax in axes.flat:
    ax.set(xlabel='Area [PE]', ylabel='Count')

# Set plot title
if data_folder[-1] == "/":
    data_folder = data_folder[:-1]
plt.suptitle(title_text, x=0.2, horizontalalignment='left', )

# Move title upwards
plt.tight_layout()

plt.show()

# %%
threshold = 3

sum_start_idx = 3
sum_end_idx = 17

test_array = np.array([0,1,2,3,4,3,4,3,4,5,6,7,8,9,10,9,8,6,5,2,1,0])

above_threshold_idx = np.where(test_array > threshold)[0]

# %%
# select indexes within range
mask_index = (above_threshold_idx >= sum_start_idx) & (above_threshold_idx <= sum_end_idx)
above_threshold_idx = above_threshold_idx[mask_index]
above_threshold_idx

# %%
# # first index of within start and end index above threshold
# sum_start_idx = above_threshold_idx[above_threshold_idx > sum_start_idx][0]
sum_end_idx = below_threshold_idx[below_threshold_idx < sum_end_idx][-1]

# %%
three_consecutive_sample_flag = 0
above_threshold_idx_diff = np.diff(above_threshold_idx)
for i, diff in enumerate(above_threshold_idx_diff):
    if diff == 1:
        three_consecutive_sample_flag += 1
    else:
        three_consecutive_sample_flag = 0

    if three_consecutive_sample_flag == 3:
        break

sum_start_idx = above_threshold_idx[i-2]
# do not update the sum_end_idx, as it is the last index of the above threshold

# %% [markdown]
# #### summed spectrum for each PE

# %%
# remove events with significant time delay > 0.1
time_array_board_0 = event_time[0]
time_array_board_1 = event_time[-1]

selected_events = np.array([])


mask_time_diff = (time_array_board_1 - time_array_board_0) < 0.1

event_time_board_0 = time_array_board_0[mask_time_diff]
event_time_board_1 = time_array_board_1[mask_time_diff]

# %%
plt.plot(event_time_board_1 - event_time_board_0)

# %%
selected_event_area = np.vstack(analysis_info.areas_PE_list)
selected_event_area = selected_event_area[:,mask_time_diff]

summed_area = np.sum(selected_event_area, axis=0)

# %%
plt.hist2d(event_time_board_0, summed_area, 
            bins=[100,100],
            # range=[[-0.1,0.1],[0,800]],
            cmap='viridis',
            norm=LogNorm())

plt.xlabel("Event time [s]")
plt.ylabel("Summed area [PE]")

# plt.colorbar(label="Counts")
plt.show()

# %%
plt.hist(summed_area, 
         bins=100, 
        #  range=[0, 10], 
         histtype='step', 
         color='red', 
         label="summed area")

# log y
plt.yscale("log")

plt.xlabel("Event time [s]")
plt.ylabel("Summed area [PE]")

# plt.colorbar(label="Counts")
plt.show()

# %% [markdown]
# ##### Remove events with satuated height

# %%
height = np.concatenate(analysis_info.heights_V_list)

fig, ax = plt.subplots(figsize=(7,7))

ax.hist(height, 
         bins=100, 
        #  range=[0, 10], 
         histtype='step', 
         color='red', 
         label="summed area")

ax.axvline(1.05, color='blue', linestyle='--', alpha=0.2)
# log y
plt.yscale("log")

plt.xlabel("Event time [s]")
plt.ylabel("Summed area [PE]")



# plt.colorbar(label="Counts")
plt.show()

# %%
# remove events with significant time delay > 0.1
time_array_board_0 = event_time[0]
time_array_board_1 = event_time[-1]

selected_events = np.array([])


mask_time_diff = (time_array_board_1 - time_array_board_0) < 0.1

event_time_board_0 = time_array_board_0[mask_time_diff]
event_time_board_1 = time_array_board_1[mask_time_diff]

selected_event_area = np.vstack(analysis_info.areas_PE_list)
selected_event_area = selected_event_area[:,mask_time_diff]

summed_area = np.sum(selected_event_area, axis=0)

selected_event_height = np.vstack(analysis_info.heights_V_list)
selected_event_height = selected_event_height[:,mask_time_diff]
mask_height = selected_event_height < 1.05

# selected_event_area = selected_event_area[mask_height]
selected_event_height = np.ma.masked_where(mask_height, selected_event_height)
selected_event_area = np.ma.masked_where(mask_height, selected_event_area)

# selected_event_area
summed_area = np.sum(selected_event_area, axis=0)

# %%
height = np.concatenate(selected_event_height)

fig, ax = plt.subplots(figsize=(7,5))

ax.hist(height, 
         bins=100, 
        #  range=[0, 10], 
         histtype='step', 
         color='red', 
         label="summed area")

ax.axvline(1.05, color='blue', linestyle='--', alpha=0.2)
# log y
plt.yscale("log")

plt.xlabel("Event time [s]")
plt.ylabel("Summed area [PE]")



# plt.colorbar(label="Counts")
plt.show()

# %%
plt.hist(summed_area, 
         bins=100, 
        #  range=[0, 10], 
         histtype='step', 
         color='red', 
         label="summed area")

# log y
plt.yscale("log")

plt.xlabel("Event time [s]")
plt.ylabel("Summed area [PE]")

# plt.colorbar(label="Counts")
plt.show()

# %%
summed_area.shape
